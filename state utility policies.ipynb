# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data/original/state_utility_policies.csv')
statepolicies=df.set_index('utility_name')

statepolicies
# Out:
#                                                       state  respondent_id  \
# utility_name
# Alabama Power Co.                                   Alabama              2
# Alaska Electric Light & Power Co.                    Alaska              3
# The Allegheny Generating Co.                       Illinois              5
# The Allegheny Generating Co.                       Maryland              5
# The Allegheny Generating Co.                       Michigan              5
# ...                                                     ...            ...
# UGI Utilities, Inc.                            Pennsylvania            428
# United Power, Inc.                                 Colorado            429
# Black Hills/Colorado Electric Utility Co., LP      Colorado            432
# Basin Electric Power Cooperative               North Dakota            531
# Basin Electric Power Cooperative                    Wyoming            531
#
# ...

# %%
statepolicies.replace(to_replace=['No','Yes'], value=[0,1])
# Out:
#                                                       state  respondent_id  \
# utility_name
# Alabama Power Co.                                   Alabama              2
# Alaska Electric Light & Power Co.                    Alaska              3
# The Allegheny Generating Co.                       Illinois              5
# The Allegheny Generating Co.                       Maryland              5
# The Allegheny Generating Co.                       Michigan              5
# ...                                                     ...            ...
# UGI Utilities, Inc.                            Pennsylvania            428
# United Power, Inc.                                 Colorado            429
# Black Hills/Colorado Electric Utility Co., LP      Colorado            432
# Basin Electric Power Cooperative               North Dakota            531
# Basin Electric Power Cooperative                    Wyoming            531
#
# ...
