# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#rps=pd.pivot_table(pd.read_csv('data/original/state_targets.csv'), values='target_value', index=['state', 'year'], aggfunc=np.sum)

rps=pd.read_csv('data/original/state_targets.csv').loc[(pd.read_csv('data/original/state_targets.csv')['target_type']=='rps_final_target')]
rps
# Out:
#               state    year       year_type legal_standard  \
# 3           Alabama     NaN  rps_final_year           None
# 8            Alaska     NaN  rps_final_year           None
# 13         Illinois    2026  rps_final_year      Executive
# 18         Maryland    2030  rps_final_year     Statutory
# 23         Michigan    2021  rps_final_year      Executive
# 28       New Jersey    2030  rps_final_year     Statutory
# 33             Ohio    2026  rps_final_year           None
# 38     Pennsylvania    2021  rps_final_year      Executive
# 43         Virginia    2050  rps_final_year           None
# 48    West Virginia     NaN  rps_final_year           None
# 53          Arizona    2025  rps_final_year           None
# 58         Arkansas     NaN  rps_final_year           None
# 63        Tennessee     NaN  rps_final_year           None
# 68            Maine    2030  rps_final_year     Statutory
# 73          Montana    2015  rps_final_year      Executive
# ...

# %%
rps.shape
# Out:
# (50, 7)
